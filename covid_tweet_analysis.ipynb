# %%
import pickle
import pandas as pd

# %%
with open("new_output_prediction.pickle", 'rb') as handle:
    tweets = pickle.load(handle)

# %%
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.DataFrame(tweets, columns = ['Tweet Content']) 
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Tweet Content
# 0     Να τες και οι ακρίδες ... το πρωί περιμένω τον Ε.T. για καφέ σπίτι #menoumespiti #convid19gr #coronavirus
# ...

# %%
with open("new_output_counts.pickle", 'rb') as handle:
    us_counts = pickle.load(handle)

# %%
print(us_counts)
# Out:
# {'03/13/20': 703, '03/22/20': 11018, '03/28/20': 8790, '03/14/20': 7973, '03/25/20': 9384}

# %%
infection_covid_tweets = []
infection_covid_tweets.append("@AndrewKirell Lots of mic fondling also at Mar-a-Lago last weekend with Bolsonaro, whose spox tested positive for #coronavirus and unconfirmed reports in Brazil that Bolsonaro did too. (Via @Z_Everson) https://t.co/h2nN5yH8j0")
infection_covid_tweets.append("@TheLastLeg #isitok for you to give a shout out to my friend Leah who had a chance to be in your studio audience tonight but couldn’t accept as she is in self-isolation with her son #coronavirus #coronapocalypse")
infection_covid_tweets.append("11 new positive cases of #COVID19 in B.C. today, Dr. Bonnie Henry says. \n\nIncludes 3 admin staff at Lion's Gate Hospital.")
infection_covid_tweets.append("VA Update: Virginia reports 1 new case of #CoronaVirus in Prince Edward County.")
infection_covid_tweets.append("1) As natives of Alabama, we've known all along that #Covid_19 was here but they just weren't testing for it. Finally, they began testing. Our 1st case was confirmed this morning, 2nd this afternoon, 3 more pending. All schools will close March 18. Some people have panicked.")
infection_covid_tweets.append("Here's our daily update in our ongoing #CoronavirusOutbreak coverage:\n\n-An employee at the Monroe Correctional Complex tested positive for #COVID19. \n-Kent officials react after a man left the quarantine site at the former motel in the city.\n\nRead more: https://t.co/J76FHGVMHC")
